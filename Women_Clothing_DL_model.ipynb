# %%
import os
import re
from zipfile import ZipFile
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
os.environ['KAGGLE_CONFIG_DIR'] =  os.getcwd()
# !kaggle datasets download -d mexwell/womens-e-commerce-clothing-reviews
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /content/kaggle.json'
# Dataset URL: https://www.kaggle.com/datasets/mexwell/womens-e-commerce-clothing-reviews
# License(s): CC0-1.0
# Downloading womens-e-commerce-clothing-reviews.zip to /content
#  72% 2.00M/2.79M [00:01<00:00, 2.07MB/s]
# 100% 2.79M/2.79M [00:01<00:00, 2.36MB/s]

# %%
def zip_file_extraction(folders = ['dataset'], file_path = os.getcwd()):
    """
    This Fuction will take input of foldername (default 'dataset')as list.
    folder path (default 'currect dir')

    """
    for folder in folders:
        folder_path = os.path.join(file_path,folder)
        if not os.path.exists(folder_path):
            os.mkdir(folder)
        else:
            print('Folder already present')
    folder_path = os.path.join(file_path,'dataset')
    for file in os.listdir(file_path):
        if file.endswith('.zip'):
            with ZipFile(file) as zobj:
                zobj.extractall(folder_path)

# %%
zip_file_extraction()

# %%
def data_reading(folder,file_path = os.getcwd()):
  path = os.path.join(file_path,folder)
  for file in os.listdir(path):
    if file.endswith('.csv'):
      print(file)
      print(path)
      f = os.path.join(path,file)
      df = pd.read_csv(f,sep = ';', on_bad_lines= 'skip')

  return df

# %%
data = data_reading('dataset')
# Out:
# Women_s_E-Commerce_Clothing_Reviews_1594_1.csv
# /content/dataset

# %%
data.head()
# Out:
#    Unnamed: 0  Clothing.ID  Age                    Title  \
# 0           1          767   33                      NaN
# 1           2         1080   34                      NaN
# 2           3         1077   60  Some major design flaws
# 3           4         1049   50         My favorite buy!
# 4           5          847   47         Flattering shirt
#
#                                          Review.Text  Rating  Recommended.IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive.Feedback.Count   Division.Name Department.Name Class.Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses

# %%
data.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23486 entries, 0 to 23485
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Clothing.ID              23486 non-null  int64
#  1   Age                      23486 non-null  int64
#  2   Title                    19676 non-null  object
#  3   Review.Text              22641 non-null  object
#  4   Rating                   23486 non-null  int64
#  5   Recommended.IND          23486 non-null  int64
#  6   Positive.Feedback.Count  23486 non-null  int64
#  7   Division.Name            23472 non-null  object
#  8   Department.Name          23472 non-null  object
#  9   Class.Name               23472 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 1.8+ MB

# %%
print('Columns\t\t\tNull Count')
print("**"*18)
print(data.isna().sum())
print("**"*18)
print("Total Null value: ",data.isna().sum().sum())
# Out:
# Columns			Null Count
# ************************************
# Clothing.ID                   0
# Age                           0
# Title                      3810
# Review.Text                 845
# Rating                        0
# Recommended.IND               0
# Positive.Feedback.Count       0
# Division.Name                14
# Department.Name              14
# Class.Name                   14
# dtype: int64
# ************************************
# Total Null value:  4697

# %%
print('Columns\t\t\tNull Count%')
print("**"*18)
print(data.isna().sum() / data.shape[0]*100)
print("**"*18)
print("Total Null value: ",data.isna().sum().sum()/data.shape[0]*100)
# Out:
# Columns			Null Count%
# ************************************
# Clothing.ID                 0.000000
# Age                         0.000000
# Title                      16.222430
# Review.Text                 3.597888
# Rating                      0.000000
# Recommended.IND             0.000000
# Positive.Feedback.Count     0.000000
# Division.Name               0.059610
# Department.Name             0.059610
# Class.Name                  0.059610
# dtype: float64
# ************************************
# Total Null value:  19.99914842885123

# %%
#dropping nan
data.dropna(inplace = True)

# %%
print('Columns\t\t\tNull Count%')
print("**"*18)
print(data.isna().sum() / data.shape[0]*100)
print("**"*18)
print("Total Null value: ",data.isna().sum().sum()/data.shape[0]*100)
# Out:
# Columns			Null Count%
# ************************************
# Clothing.ID                0.0
# Age                        0.0
# Title                      0.0
# Review.Text                0.0
# Rating                     0.0
# Recommended.IND            0.0
# Positive.Feedback.Count    0.0
# Division.Name              0.0
# Department.Name            0.0
# Class.Name                 0.0
# dtype: float64
# ************************************
# Total Null value:  0.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19662 entries, 2 to 23485
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Clothing.ID              19662 non-null  int64
#  1   Age                      19662 non-null  int64
#  2   Title                    19662 non-null  object
#  3   Review.Text              19662 non-null  object
#  4   Rating                   19662 non-null  int64
#  5   Recommended.IND          19662 non-null  int64
#  6   Positive.Feedback.Count  19662 non-null  int64
#  7   Division.Name            19662 non-null  object
#  8   Department.Name          19662 non-null  object
#  9   Class.Name               19662 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 1.7+ MB

# %%
#renaming the columns
cols = {

        'Clothing.ID' : "Id",
        'Review.Text' : 'Review',
        'Recommended.IND' : 'Recommended',
        'Positive.Feedback.Count' : 'Feedback',
        'Division.Name' : 'Division',
        'Department.Name' : 'Department',
        'Class.Name' : 'Class'
}

data.rename(columns = cols, inplace= True)

# %%
data.columns
# Out:
# Index(['Id', 'Age', 'Title', 'Review', 'Rating', 'Recommended', 'Feedback',
#        'Division', 'Department', 'Class'],
#       dtype='object')

# %%
def feature_joining(row):
    combine = ""
    combine += f"Product is of Division: {row['Division']}, department: {row['Department']}, class: {row['Class']}. "
    combine += f"I am {str(row['Age'])} years old. I rate the product {str(row['Rating'])}. "
    combine += f"Title of the review is {row['Title']}. "
    combine += row['Review']
    return combine

# %%
data['Combine_text'] = data.apply(feature_joining, axis = 1)

# %%
data.reset_index(drop = True, inplace =True)

# %%
data['Combine_text'][0]
# Out:
# 'Product is of Division: General, department: Dresses, class: Dresses. I am 60 years old. I rate the product 3. Title of the review is Some major design flaws. I had such high hopes for this dress and really wanted it to work for me. i initially ordered the petite small (my usual size) but i found this to be outrageously small. so small in fact that i could not zip it up! i reordered it in petite medium, which was just ok. overall, the top half was comfortable and fit nicely, but the bottom half had a very tight under layer and several somewhat cheap (net) over layers. imo, a major design flaw was the net over layer sewn directly into the zipper - it c'

# %%
def preprocessing(text):
  text = text.strip().lower()
  text = re.sub("[^A-Za-z0-9]"," ",text)
  words = text.split(" ")
  STOPWORDS = set(stopwords.words('english'))
  lemitizer = WordNetLemmatizer()
  clean_words = [lemitizer.lemmatize(word) for word in words if word not in STOPWORDS]
  return ' '.join(clean_words)

# %%
data['Combine_text'] = data['Combine_text'].apply(preprocessing)

# %%
# %matplotlib inline
from wordcloud import WordCloud
text = ' '.join(data['Combine_text'].values)
wc = WordCloud(background_color= 'white', max_words = 100).generate(text)
plt.figure(figsize=(8,8))
plt.imshow(wc)
plt.title('Top 100 words')
plt.axis('off')
plt.show()

# %%
#data splitting
X = data['Combine_text']
Y = data['Recommended']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y, random_state= 42, test_size= 0.2)

# %%
from keras.preprocessing.text import Tokenizer

token = Tokenizer(oov_token= "<unknown>")
token.fit_on_texts(X_train)

# %%
train_sequence = token.texts_to_sequences(X_train)
test_sequence = token.texts_to_sequences(X_test)

# %%
length = []
for i in train_sequence:
  length.append(len(i))
max_review_length = max(length)
print("Max Review length: ", max_review_length)
# Out:
# Max Review length:  87

# %%
from keras.utils import pad_sequences
train_sequence = pad_sequences(train_sequence, maxlen= max_review_length, padding= 'post')
test_sequence = pad_sequences(test_sequence, maxlen= max_review_length, padding= 'post')

# %%
unique_word_count = len(token.word_index)
unique_word_count
# Out:
# 11567

# %%
from tensorflow import keras
def get_model(max_len = max_review_length, max_words = unique_word_count, ):
  input = keras.Input(name = 'input', shape = [max_len,])
  layer = keras.layers.Embedding(input_dim = max_words, input_length = max_len, output_dim = 100, name = 'Embedding')(input)
  layer = keras.layers.Bidirectional(keras.layers.LSTM(128),name = 'Bidirectional')(layer)
  layer = keras.layers.Dropout(0.5)(layer)
  layer = keras.layers.Dense(64, activation = 'relu')(layer)
  layer = keras.layers.Dropout(0.3)(layer)
  layer = keras.layers.Dense(64, activation = 'relu')(layer)
  layer = keras.layers.Dense(64, activation = 'relu', kernel_regularizer=keras.regularizers.L2(0.01))(layer)
  layer = keras.layers.Dropout(0.3)(layer)
  layer = keras.layers.Dense(64, activation = 'relu',kernel_regularizer=keras.regularizers.L2(0.01))(layer)
  output = keras.layers.Dense(1, activation = 'sigmoid')(layer)
  model = keras.Model(input, output)
  model.compile(optimizer = 'adam',
                loss = 'binary_crossentropy',
                metrics = ['accuracy'])
  return model

# %%
model = get_model()

# %%
model.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 87)]              0
#
#  Embedding (Embedding)       (None, 87, 100)           1156700
#
#  Bidirectional (Bidirection  (None, 256)               234496
#  al)
#
#  dropout_13 (Dropout)        (None, 256)               0
#
#  dense_23 (Dense)            (None, 64)                16448
#
#  dropout_14 (Dropout)        (None, 64)                0
#
#  dense_24 (Dense)            (None, 64)                4160
#
#  dense_25 (Dense)            (None, 64)                4160
#
#  dropout_15 (Dropout)        (None, 64)                0
#
#  dense_26 (Dense)            (None, 64)                4160
#
#  dense_27 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 1420189 (5.42 MB)
# Trainable params: 1420189 (5.42 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(train_sequence, np.array(y_train), epochs = 50, validation_split = 0.2)
# Out:
# Epoch 1/50
# 394/394 [==============================] - 26s 54ms/step - loss: 0.5717 - accuracy: 0.8842 - val_loss: 0.2061 - val_accuracy: 0.9393
# Epoch 2/50
# 394/394 [==============================] - 8s 21ms/step - loss: 0.1897 - accuracy: 0.9369 - val_loss: 0.1549 - val_accuracy: 0.9425
# Epoch 3/50
# 394/394 [==============================] - 6s 15ms/step - loss: 0.1522 - accuracy: 0.9483 - val_loss: 0.1563 - val_accuracy: 0.9383
# Epoch 4/50
# 394/394 [==============================] - 7s 18ms/step - loss: 0.1195 - accuracy: 0.9588 - val_loss: 0.2233 - val_accuracy: 0.9326
# Epoch 5/50
# 394/394 [==============================] - 6s 14ms/step - loss: 0.0920 - accuracy: 0.9692 - val_loss: 0.2588 - val_accuracy: 0.9250
# Epoch 6/50
# 394/394 [==============================] - 7s 18ms/step - loss: 0.0704 - accuracy: 0.9793 - val_loss: 0.1819 - val_accuracy: 0.9355
# Epoch 7/50
# 394/394 [==============================] - 6s 16ms/step - loss: 0.0599 - accuracy: 0.9831 - val_loss: 0.4251 - val_accuracy: 0.9240
# Epoch 8/50
# 394/394 [==============================] - 7s 19ms/step - loss: 0.0404 - accuracy: 0.9882 - val_loss: 0.3789 - val_accuracy: 0.9123
# Epoch 9/50
# 394/394 [==============================] - 5s 13ms/step - loss: 0.0301 - accuracy: 0.9923 - val_loss: 0.5471 - val_accuracy: 0.9253
# Epoch 10/50
# 394/394 [==============================] - 8s 19ms/step - loss: 0.0203 - accuracy: 0.9951 - val_loss: 0.4556 - val_accuracy: 0.9256
# Epoch 11/50
# 394/394 [==============================] - 6s 15ms/step - loss: 0.0234 - accuracy: 0.9942 - val_loss: 0.5304 - val_accuracy: 0.9291
# Epoch 12/50
# 394/394 [==============================] - 6s 16ms/step - loss: 0.0129 - accuracy: 0.9974 - val_loss: 0.3395 - val_accuracy: 0.9215
# Epoch 13/50
# 394/394 [==============================] - 5s 13ms/step - loss: 0.0224 - accuracy: 0.9946 - val_loss: 0.5222 - val_accuracy: 0.9240
# Epoch 14/50
# 394/394 [==============================] - 6s 15ms/step - loss: 0.0112 - accuracy: 0.9974 - val_loss: 0.3818 - val_accuracy: 0.9247
# Epoch 15/50
# 394/394 [==============================] - 6s 14ms/step - loss: 0.0189 - accuracy: 0.9956 - val_loss: 0.4418 - val_accuracy: 0.9272
# Epoch 16/50
# 394/394 [==============================] - 5s 13ms/step - loss: 0.0212 - accuracy: 0.9955 - val_loss: 0.5205 - val_accuracy: 0.9282
# Epoch 17/50
# 394/394 [==============================] - 6s 15ms/step - loss: 0.0206 - accuracy: 0.9957 - val_loss: 0.3498 - val_accuracy: 0.9234
# Epoch 18/50
# 394/394 [==============================] - 5s 13ms/step - loss: 0.0090 - accuracy: 0.9979 - val_loss: 0.6616 - val_accuracy: 0.9231
# Epoch 19/50
# 394/394 [==============================] - 6s 15ms/step - loss: 0.0024 - accuracy: 0.9998 - val_loss: 0.6431 - val_accuracy: 0.9224
# Epoch 20/50
# 394/394 [==============================] - 5s 13ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.6441 - val_accuracy: 0.9215
# Epoch 21/50
# 394/394 [==============================] - 5s 14ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.6540 - val_accuracy: 0.9228
# Epoch 22/50
# 394/394 [==============================] - 6s 15ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.7138 - val_accuracy: 0.9186
# Epoch 23/50
# 394/394 [==============================] - 5s 13ms/step - loss: 9.9186e-04 - accuracy: 1.0000 - val_loss: 0.7160 - val_accuracy: 0.9186
# Epoch 24/50
# 394/394 [==============================] - 6s 15ms/step - loss: 9.0346e-04 - accuracy: 1.0000 - val_loss: 0.7248 - val_accuracy: 0.9196
# Epoch 25/50
# 394/394 [==============================] - 6s 15ms/step - loss: 8.1254e-04 - accuracy: 1.0000 - val_loss: 0.7976 - val_accuracy: 0.9174
# Epoch 26/50
# 394/394 [==============================] - 6s 15ms/step - loss: 6.9363e-04 - accuracy: 1.0000 - val_loss: 0.8153 - val_accuracy: 0.9180
# Epoch 27/50
# 394/394 [==============================] - 5s 13ms/step - loss: 6.1821e-04 - accuracy: 1.0000 - val_loss: 0.9184 - val_accuracy: 0.9164
# Epoch 28/50
# 394/394 [==============================] - 5s 14ms/step - loss: 5.8536e-04 - accuracy: 1.0000 - val_loss: 1.9204 - val_accuracy: 0.9142
# Epoch 29/50
# 394/394 [==============================] - 6s 14ms/step - loss: 4.5440e-04 - accuracy: 1.0000 - val_loss: 0.9329 - val_accuracy: 0.9164
# Epoch 30/50
# 394/394 [==============================] - 5s 13ms/step - loss: 5.4325e-04 - accuracy: 1.0000 - val_loss: 0.9766 - val_accuracy: 0.9167
# Epoch 31/50
# 394/394 [==============================] - 6s 16ms/step - loss: 3.4173e-04 - accuracy: 1.0000 - val_loss: 0.9969 - val_accuracy: 0.9170
# Epoch 32/50
# 394/394 [==============================] - 5s 13ms/step - loss: 0.0043 - accuracy: 0.9998 - val_loss: 10.0077 - val_accuracy: 0.9148
# Epoch 33/50
# 394/394 [==============================] - 6s 15ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 3.4244 - val_accuracy: 0.9129
# Epoch 34/50
# 394/394 [==============================] - 5s 12ms/step - loss: 0.0843 - accuracy: 0.9800 - val_loss: 0.4957 - val_accuracy: 0.9170
# Epoch 35/50
# 394/394 [==============================] - 6s 15ms/step - loss: 0.0281 - accuracy: 0.9932 - val_loss: 0.3571 - val_accuracy: 0.9253
# Epoch 36/50
# 394/394 [==============================] - 5s 14ms/step - loss: 0.0164 - accuracy: 0.9956 - val_loss: 0.4561 - val_accuracy: 0.9285
# Epoch 37/50
# 394/394 [==============================] - 5s 13ms/step - loss: 0.0082 - accuracy: 0.9980 - val_loss: 0.5500 - val_accuracy: 0.9278
# Epoch 38/50
# 394/394 [==============================] - 6s 15ms/step - loss: 0.0087 - accuracy: 0.9980 - val_loss: 0.3646 - val_accuracy: 0.9285
# Epoch 39/50
# 394/394 [==============================] - 5s 13ms/step - loss: 0.0096 - accuracy: 0.9979 - val_loss: 0.6936 - val_accuracy: 0.9269
# Epoch 40/50
# 394/394 [==============================] - 6s 15ms/step - loss: 0.0071 - accuracy: 0.9983 - val_loss: 0.7735 - val_accuracy: 0.9253
# Epoch 41/50
# 394/394 [==============================] - 5s 13ms/step - loss: 0.0045 - accuracy: 0.9997 - val_loss: 0.5965 - val_accuracy: 0.9329
# Epoch 42/50
# 394/394 [==============================] - 6s 14ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.6958 - val_accuracy: 0.9288
# Epoch 43/50
# 394/394 [==============================] - 6s 14ms/step - loss: 8.1118e-04 - accuracy: 1.0000 - val_loss: 0.6557 - val_accuracy: 0.9269
# Epoch 44/50
# 394/394 [==============================] - 5s 14ms/step - loss: 6.5519e-04 - accuracy: 1.0000 - val_loss: 0.6633 - val_accuracy: 0.9263
# Epoch 45/50
# 394/394 [==============================] - 6s 15ms/step - loss: 5.7184e-04 - accuracy: 1.0000 - val_loss: 0.7716 - val_accuracy: 0.9263
# Epoch 46/50
# 394/394 [==============================] - 7s 19ms/step - loss: 4.9488e-04 - accuracy: 1.0000 - val_loss: 0.8457 - val_accuracy: 0.9250
# Epoch 47/50
# 394/394 [==============================] - 9s 23ms/step - loss: 5.1417e-04 - accuracy: 1.0000 - val_loss: 0.8556 - val_accuracy: 0.9250
# Epoch 48/50
# 394/394 [==============================] - 9s 22ms/step - loss: 4.1034e-04 - accuracy: 1.0000 - val_loss: 0.8436 - val_accuracy: 0.9259
# Epoch 49/50
# 394/394 [==============================] - 6s 15ms/step - loss: 4.2914e-04 - accuracy: 1.0000 - val_loss: 0.9373 - val_accuracy: 0.9247
# Epoch 50/50
# 394/394 [==============================] - 5s 13ms/step - loss: 3.4285e-04 - accuracy: 1.0000 - val_loss: 1.2405 - val_accuracy: 0.9250

# %%
plt.plot(history.history['accuracy'], 'r')
plt.plot(history.history['val_accuracy'], 'b')
plt.title("Train Acc Vs Validation Acc")
plt.show()

# %%
from sklearn.metrics import f1_score, confusion_matrix, classification_report
y_pred = model.predict(test_sequence)
y_pred = (y_pred > 0.5).astype(int)
print("**"*20)
print(classification_report(y_test, y_pred))
print("**"*20)
print(f"f1 Score: ", round(f1_score(y_test, y_pred),2))
# Out:
# 123/123 [==============================] - 1s 5ms/step
# ****************************************
#               precision    recall  f1-score   support
#
#            0       0.83      0.78      0.80       700
#            1       0.95      0.97      0.96      3233
#
#     accuracy                           0.93      3933
#    macro avg       0.89      0.87      0.88      3933
# weighted avg       0.93      0.93      0.93      3933
#
# ****************************************
# f1 Score:  0.96

# %%
sns.heatmap(confusion_matrix(y_test, y_pred), annot= True, fmt = '.0f')
# Out:
# <Axes: >

# %%
model.save('women_clothing.keras')

# %%
model1 = keras.models.load_model('women_clothing.h5')

# %%
model1.predict(test_sequence)
# Out:
# 123/123 [==============================] - 1s 5ms/step
# array([[1.],
#        [1.],
#        [1.],
#        ...,
#        [1.],
#        [1.],
#        [1.]], dtype=float32)
